# %% [markdown]
# # nb004に追加していく

# %%
import os

import math

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import texthero as hero
from texthero import preprocessing

import warnings
warnings.filterwarnings("ignore")


sns.set_style('ticks')

# %%
INPUT_DIR = '../data/inputs/'
OUTPUT_DIR = '../data/outputs/'

os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
train_df = pd.read_csv(os.path.join(INPUT_DIR, 'train.csv'))
test_df = pd.read_csv(os.path.join(INPUT_DIR, 'test.csv'))

# %%
# Publicher==Unknownと言う会社はなくて、NaNの入力ミスと仮定
test_df.query('Publisher == "Unknown"').replace('Unknown', np.nan)
# Out:
#                                            Name Platform  Year_of_Release  \
# 5     Cubix Robots for Everyone: Clash 'n' Bash      GBA              NaN
# 8          Nicktoons: Battle for Volcano Island       GC              NaN
# 12                   Twisted Metal: Small Brawl       PS              NaN
# 13                                  Teen Titans      GBA              NaN
# 16                      Jurassic Park: The Game     X360              NaN
# ...                                         ...      ...              ...
# 8168               Sengoku Otome: Legend Battle      PSV           2016.0
# 8200                Ao no Kanata no Four Rhythm      PSV           2016.0
# 8208             Shitsuji ga Aruji o Erabu Toki      PSV           2016.0
# 8214                           Strawberry Nauts      PSV           2016.0
# 8286                                  Persona 5      PS3           2016.0
#
#              Genre  Publisher  Critic_Score  Critic_Count User_Score  \
# 5           Action        NaN           NaN           NaN        NaN
# 8           Action        NaN           NaN           NaN          7
# 12          Action        NaN          51.0          14.0        7.6
# 13          Action        NaN          61.0           9.0        tbd
# 16          Action        NaN          60.0           9.0        3.6
# ...            ...        ...           ...           ...        ...
# 8168        Action        NaN           NaN           NaN        NaN
# 8200     Adventure        NaN           NaN           NaN        NaN
# 8208     Adventure        NaN           NaN           NaN        NaN
# 8214     Adventure        NaN           NaN           NaN        NaN
# 8286  Role-Playing        NaN           NaN           NaN        NaN
#
#       User_Count                     Developer Rating
# 5            NaN                           NaN    NaN
# 8            4.0     Blue Tongue Entertainment      E
# 12          49.0                Incognito Inc.      T
# 13           NaN  Artificial Mind and Movement   E10+
# 16         138.0                Telltale Games      T
# ...          ...                           ...    ...
# 8168         NaN                           NaN    NaN
# 8200         NaN                           NaN    NaN
# 8208         NaN                           NaN    NaN
# 8214         NaN                           NaN    NaN
# 8286         NaN                         Atlus    NaN
#
# [201 rows x 11 columns]

# %%
whole_df = pd.concat([train_df, test_df], ignore_index=True)

# %%
train_df.head()
# Out:
#                                           Name Platform  Year_of_Release  \
# 0                   LEGO Batman: The Videogame      Wii              NaN
# 1  LEGO Indiana Jones: The Original Adventures      Wii              NaN
# 2                   LEGO Batman: The Videogame      PSP              NaN
# 3                                       Combat     2600              NaN
# 4                 LEGO Harry Potter: Years 5-7      Wii              NaN
#
#     Genre                               Publisher  NA_Sales  EU_Sales  \
# 0  Action  Warner Bros. Interactive Entertainment       180        97
# 1  Action                               LucasArts       151        61
# 2  Action  Warner Bros. Interactive Entertainment        56        44
# 3  Action                                   Atari       117         7
# 4  Action  Warner Bros. Interactive Entertainment        69        42
#
#    JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# 0         0           28           306          74.0          17.0        7.9
# 1         0           21           234          78.0          22.0        6.6
# 2         0           27           128          73.0           5.0        7.4
# 3         0            1           125           NaN           NaN        NaN
# 4         0           12           124          76.0           8.0        7.8
#
#    User_Count          Developer Rating
# 0        22.0  Traveller's Tales   E10+
# 1        28.0  Traveller's Tales   E10+
# 2        10.0  Traveller's Tales   E10+
# 3         NaN                NaN    NaN
# 4        13.0  Traveller's Tales   E10+

# %%
test_df.head()
# Out:
#                             Name Platform  Year_of_Release   Genre  \
# 0      Hitman 2: Silent Assassin       XB              NaN  Action
# 1    Legacy of Kain: Soul Reaver       PS              NaN  Action
# 2  Metal Gear Solid 2: Substance       XB              NaN  Action
# 3        Silent Hill: Homecoming     X360              NaN  Action
# 4        Silent Hill: Homecoming      PS3              NaN  Action
#
#                       Publisher  Critic_Score  Critic_Count User_Score  \
# 0             Eidos Interactive          84.0          23.0          8
# 1             Eidos Interactive          91.0          17.0          9
# 2  Konami Digital Entertainment          87.0          28.0        8.5
# 3  Konami Digital Entertainment          70.0          54.0        6.9
# 4  Konami Digital Entertainment          71.0          41.0        6.9
#
#    User_Count           Developer Rating
# 0        19.0      Io Interactive      M
# 1       132.0    Crystal Dynamics      T
# 2        39.0                KCEJ      M
# 3       180.0  Double Helix Games      M
# 4       143.0  Double Helix Games      M

# %%
# name、publicher、developerの情報は落とすかうまいこと使いたい

# %%
# test_df['Platform'].isnull().sum()
# test_df['Genre'].isnull().sum()
test_df[test_df['Genre'].isnull()]

"""
wikiみると1993年Game Gearで発売のスパイダーマンのゲームっぽい
https://ja.wikipedia.org/wiki/アクレイム・エンタテインメント
Actionだけどこれを入れると外部情報の使用になるのでGEN_NANかなあ
"""
# Out:
# '\nwikiみると1993年Game Gearで発売のスパイダーマンのゲームっぽい\nhttps://ja.wikipedia.org/wiki/アクレイム・エンタテインメント\nActionだけどこれを入れると外部情報の使用になるのでGEN_NANかなあ\n'

# %%
def _platform_genre(x):
    p = x['Platform'].lower() if x['Platform'] else 'nan'

    judge_g = x['Genre'] if type(x['Genre']) == str else 'nan'
    g = judge_g.lower() if judge_g != 'nan' else 'nan'
    p_and_g = "{}_{}".format(p,g) 
    return p_and_g

test_df['Platform_and_Genre'] = test_df.apply(_platform_genre, axis=1)
train_df['Platform_and_Genre'] = train_df.apply(_platform_genre, axis=1)

test_df.head()
# Out:
#                             Name Platform  Year_of_Release   Genre  \
# 0      Hitman 2: Silent Assassin       XB              NaN  Action
# 1    Legacy of Kain: Soul Reaver       PS              NaN  Action
# 2  Metal Gear Solid 2: Substance       XB              NaN  Action
# 3        Silent Hill: Homecoming     X360              NaN  Action
# 4        Silent Hill: Homecoming      PS3              NaN  Action
#
#                       Publisher  Critic_Score  Critic_Count User_Score  \
# 0             Eidos Interactive          84.0          23.0          8
# 1             Eidos Interactive          91.0          17.0          9
# 2  Konami Digital Entertainment          87.0          28.0        8.5
# 3  Konami Digital Entertainment          70.0          54.0        6.9
# 4  Konami Digital Entertainment          71.0          41.0        6.9
#
#    User_Count           Developer Rating Platform_and_Genre
# 0        19.0      Io Interactive      M          xb_action
# 1       132.0    Crystal Dynamics      T          ps_action
# 2        39.0                KCEJ      M          xb_action
# 3       180.0  Double Helix Games      M        x360_action
# 4       143.0  Double Helix Games      M         ps3_action

# %%
# ScoreとCountを掛け算してみて影響しないかな

import pandas as pd
from sklearn.preprocessing import MinMaxScaler

train_df['User_Score'] = train_df['User_Score'].replace('tbd', None).astype(float)
test_df['User_Score'] = test_df['User_Score'].replace('tbd', None).astype(float)

# scaler = MinMaxScaler()

# MinMaxで正規化
# train_df[['Critic_Score', 'User_Score']] = scaler.fit_transform(train_df[['Critic_Score', 'User_Score']]) # A, Bカラムのみを正規化
# test_df[['Crtest_df.query('Rating == "RP"').replace("RP", np.nan)
# test_df.query('Rating == "RP"').replace("RP", np.nan)

# Criticに関して
train_df['Critic_Count_times_Score'] = train_df.apply(lambda x: x['Critic_Count']*x['Critic_Score'], axis=1)
test_df['Critic_Count_times_Score'] = test_df.apply(lambda x: x['Critic_Count']*x['Critic_Score'], axis=1)

# Userに関して
train_df['User_Count_times_Score'] = train_df.apply(lambda x: x['User_Count']*x['User_Score'], axis=1)
test_df['User_Count_times_Score'] = test_df.apply(lambda x: x['User_Count']*x['User_Score'], axis=1)

# %%
# user_scoreとcritic_scoreの平均値を出す


train_df['Mean_Critic_Score'] = train_df.apply(lambda x: x['Critic_Score'] / x['Critic_Count'], axis=1)
train_df['Mean_User_Score'] = train_df.apply(lambda x: x['User_Score'] / x['User_Count'], axis=1)

test_df['Mean_Critic_Score'] = test_df.apply(lambda x: x['Critic_Score'] / x['Critic_Count'], axis=1)
test_df['Mean_User_Score'] = test_df.apply(lambda x: x['User_Score'] / x['User_Count'], axis=1)

# %%
# 雑に評論家とユーザーのスコアの乖離度合いを計算する
# CriticScoreは100点満点、UserScoreは10点満点なので、CS - US*10する

train_df['Difference_Between_Critics_And_Users'] = train_df.apply(lambda x: x['Critic_Score'] - x['User_Score']*10, axis=1)
test_df['Difference_Between_Critics_And_Users'] = test_df.apply(lambda x: x['Critic_Score'] - x['User_Score']*10, axis=1)

# %%
train_df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating',
#        'Platform_and_Genre', 'Critic_Count_times_Score',
#        'User_Count_times_Score', 'Mean_Critic_Score', 'Mean_User_Score',
#        'Difference_Between_Critics_And_Users'],
#       dtype='object')

# %%
# 販売年が何年行こうか reportの分布から1990,2000,2010で分けてみる

def _check_year(x):
    if x < 1990:
        return 'A'
    elif x < 2000:
        return 'B'
    elif x < 2010:
        return'C'
    elif x >= 2010:
        return 'D'
    else:
        return 'E'


# tmp_df = train_df.copy()
# tmp_df['Year_category'] = tmp_df['Year_of_Release'].apply(_check_year)
# tmp_df.query('Year_category == "A"')

train_df['Year_category'] = train_df['Year_of_Release'].apply(_check_year)
test_df['Year_category'] = test_df['Year_of_Release'].apply(_check_year)

# %%
train_df['Genre'].unique()
# Out:
# array(['Action', 'Adventure', 'Fighting', 'Misc', 'Platform', 'Puzzle',
#        'Racing', 'Role-Playing', 'Shooter', 'Simulation', 'Sports',
#        'Strategy'], dtype=object)

# %%
# 一杯genreを出している会社は大きいところ？

def _publisher_genre_count(x):
    pub = x['Publisher']
    genre_count = len(whole_df.query('Publisher == @pub')['Genre'].unique())
    return genre_count


# tmp_df = train_df.copy()


train_df['Publisher_Genre_Count'] = train_df.apply(_publisher_genre_count,axis=1)

# %%
test_df['Publisher_Genre_Count'] = test_df.apply(_publisher_genre_count,axis=1)
train_df.head()
# Out:
#                                           Name Platform  Year_of_Release  \
# 0                   LEGO Batman: The Videogame      Wii              NaN
# 1  LEGO Indiana Jones: The Original Adventures      Wii              NaN
# 2                   LEGO Batman: The Videogame      PSP              NaN
# 3                                       Combat     2600              NaN
# 4                 LEGO Harry Potter: Years 5-7      Wii              NaN
#
#     Genre                               Publisher  NA_Sales  EU_Sales  \
# 0  Action  Warner Bros. Interactive Entertainment       180        97
# 1  Action                               LucasArts       151        61
# 2  Action  Warner Bros. Interactive Entertainment        56        44
# 3  Action                                   Atari       117         7
# 4  Action  Warner Bros. Interactive Entertainment        69        42
#
#    JP_Sales  Other_Sales  Global_Sales  ...          Developer  Rating  \
# 0         0           28           306  ...  Traveller's Tales    E10+
# 1         0           21           234  ...  Traveller's Tales    E10+
# 2         0           27           128  ...  Traveller's Tales    E10+
# 3         0            1           125  ...                NaN     NaN
# 4         0           12           124  ...  Traveller's Tales    E10+
#
#    Platform_and_Genre  Critic_Count_times_Score User_Count_times_Score  \
# 0          wii_action                    1258.0                  173.8
# 1          wii_action                    1716.0                  184.8
# 2          psp_action                     365.0                   74.0
# 3         2600_action                       NaN                    NaN
# 4          wii_action                     608.0                  101.4
#
#   Mean_Critic_Score Mean_User_Score  Difference_Between_Critics_And_Users  \
# 0          4.352941        0.359091                                  -5.0
# 1          3.545455        0.235714                                  12.0
# 2         14.600000        0.740000                                  -1.0
# 3               NaN             NaN                                   NaN
# 4          9.500000        0.600000                                  -2.0
#
#    Year_category  Publisher_Genre_Count
# 0              E                      9
# 1              E                      7
# 2              E                      9
# 3              E                     12
# 4              E                      9
#
# [5 rows x 24 columns]

# %%
# https://www.guruguru.science/competitions/13/discussions/8c7a3e1b-55f8-4c93-9897-b331346afbfd/
# takabyさんのを参考にKmeansをいれる。PCA入れたら下がったので一旦除外

# カラムを絞る
train_name = train_df[['Name', 'Global_Sales']]
test_name = test_df[['Name']]

# Nameを綺麗にする
custom_pipeline = [preprocessing.fillna
                   , preprocessing.lowercase
                   , preprocessing.remove_digits
                   , preprocessing.remove_punctuation
                   , preprocessing.remove_diacritics
                   , preprocessing.remove_whitespace
                  ]
train_name['clean_Name'] = hero.clean(train_name['Name'], pipeline=custom_pipeline)
test_name['clean_Name'] = hero.clean(test_name['Name'], pipeline=custom_pipeline)

df_name = pd.concat([train_name, test_name], axis=0, sort=False).reset_index(drop=True)

df_name['kmeans'] = (
    df_name['clean_Name']
    .pipe(hero.tfidf)
    .pipe(hero.kmeans)
)

# 良くなかった
# df_name['pca'] = (
#     df_name['clean_Name']
#     .pipe(hero.tfidf)
#     .pipe(hero.pca)
# )

kmeans_dic = {}
names = df_name['Name'].to_list()
kmeans = df_name['kmeans'].to_list()

for name, kv in zip(names, kmeans):
    # kmeans_dic[name] = {'kmeans': kv, 'pca': p}
    kmeans_dic[name] = kv



train_df['Kmeans'] = train_df['Name'].apply(lambda x : kmeans_dic[x])
test_df['Kmeans'] = test_df['Name'].apply(lambda x : kmeans_dic[x])


# train_df['PCA'] = train_df['Name'].apply(lambda x : kmeans_dic[x]['pca'])
# test_df['PCA'] = test_df['Name'].apply(lambda x : kmeans_dic[x]['pca'])

# %%
# tbdの処理でNoneにする
def preprocess(input_df: pd.DataFrame) -> pd.DataFrame:
    output_df = input_df.copy()
    
    idx_tbd = input_df['User_Score'] == 'tbd'
    output_df['User_Score_is_tbd'] = idx_tbd.astype(int)
    
    output_df['User_Score'] = input_df['User_Score'].replace('tbd', None).astype(float)
    return output_df

# 連続変数のコピー
def create_continuous_features(input_df):
    input_df = preprocess(input_df)
    use_columns = [
        # 連続変数
        'Critic_Score',
        'Critic_Count', 
        'User_Score', 
        'User_Count',
        'Year_of_Release',
        'User_Score_is_tbd',
        'User_Count_times_Score',
        'Critic_Count_times_Score',
        'Mean_Critic_Score',
        'Mean_User_Score',
        'Difference_Between_Critics_And_Users',
        'Publisher_Genre_Count'
    ]
    return input_df[use_columns].copy()

# %%
def _is_violence(x):
    if type(x) == str:
        if x.lower() in ['m', 'ao']:
            return 'violence'
        else:
            return 'not_violence'
    else:
        return None



train_df['Violence'] = train_df['Rating'].apply(_is_violence)
test_df['Violence'] = test_df['Rating'].apply(_is_violence)

# %%
train_df.head()
# Out:
#                                           Name Platform  Year_of_Release  \
# 0                   LEGO Batman: The Videogame      Wii              NaN
# 1  LEGO Indiana Jones: The Original Adventures      Wii              NaN
# 2                   LEGO Batman: The Videogame      PSP              NaN
# 3                                       Combat     2600              NaN
# 4                 LEGO Harry Potter: Years 5-7      Wii              NaN
#
#     Genre                               Publisher  NA_Sales  EU_Sales  \
# 0  Action  Warner Bros. Interactive Entertainment       180        97
# 1  Action                               LucasArts       151        61
# 2  Action  Warner Bros. Interactive Entertainment        56        44
# 3  Action                                   Atari       117         7
# 4  Action  Warner Bros. Interactive Entertainment        69        42
#
#    JP_Sales  Other_Sales  Global_Sales  ...  Platform_and_Genre  \
# 0         0           28           306  ...          wii_action
# 1         0           21           234  ...          wii_action
# 2         0           27           128  ...          psp_action
# 3         0            1           125  ...         2600_action
# 4         0           12           124  ...          wii_action
#
#    Critic_Count_times_Score  User_Count_times_Score  Mean_Critic_Score  \
# 0                    1258.0                   173.8           4.352941
# 1                    1716.0                   184.8           3.545455
# 2                     365.0                    74.0          14.600000
# 3                       NaN                     NaN                NaN
# 4                     608.0                   101.4           9.500000
#
#   Mean_User_Score Difference_Between_Critics_And_Users Year_category  \
# 0        0.359091                                 -5.0             E
# 1        0.235714                                 12.0             E
# 2        0.740000                                 -1.0             E
# 3             NaN                                  NaN             E
# 4        0.600000                                 -2.0             E
#
#    Publisher_Genre_Count  Kmeans      Violence
# 0                      9       2  not_violence
# 1                      7       2  not_violence
# 2                      9       2  not_violence
# 3                     12       0          None
# 4                      9       0  not_violence
#
# [5 rows x 26 columns]

# %%
# https://www.guruguru.science/competitions/13/discussions/8c7a3e1b-55f8-4c93-9897-b331346afbfd/
# 同じくtakabyさんのを参考に出現頻度の高い単語でlegoとかsoccerとかでboolean特徴量を作る

# trainとtestに共通してそうな単語
# lego,soccer,super,world,wars,dragon,nba,


def _check_word_in(x, word):
    if type(x) == str:
        if word in x.lower():
            return True
        else:
            return False
    else:
        return False


train_df['Name_in_lego'] = train_df['Name'].apply(lambda x: _check_word_in(x, 'lego'))
train_df['Name_in_soccer'] = train_df['Name'].apply(lambda x: _check_word_in(x, 'soccer'))
train_df['Name_in_super'] = train_df['Name'].apply(lambda x: _check_word_in(x, 'super'))
train_df['Name_in_world'] = train_df['Name'].apply(lambda x: _check_word_in(x, 'world'))
train_df['Name_in_wars'] = train_df['Name'].apply(lambda x: _check_word_in(x, 'wars'))
train_df['Name_in_nba'] = train_df['Name'].apply(lambda x: _check_word_in(x, 'nba'))

test_df['Name_in_lego'] = test_df['Name'].apply(lambda x: _check_word_in(x, 'lego'))
test_df['Name_in_soccer'] = test_df['Name'].apply(lambda x: _check_word_in(x,'soccer'))
test_df['Name_in_super'] = test_df['Name'].apply(lambda x: _check_word_in(x,'super'))
test_df['Name_in_world'] = test_df['Name'].apply(lambda x: _check_word_in(x,'world'))
test_df['Name_in_wars'] = test_df['Name'].apply(lambda x: _check_word_in(x,'wars'))
test_df['Name_in_nba'] = test_df['Name'].apply(lambda x: _check_word_in(x,'nba'))


list_name_in = ['Name_in_lego', 'Name_in_soccer', 'Name_in_super', 'Name_in_world', 'Name_in_wars', 'Name_in_nba']
train_df[list_name_in] = train_df[list_name_in] * 1
test_df[list_name_in] = test_df[list_name_in] * 1

# %%
def create_boolean_feature(input_df):
    output_df = pd.DataFrame()
    
    texts = [
        'PS'
    ]
    
    for t in texts:
        output_df[f'Platform_has_{t}'] = input_df['Platform'].fillna('').str.lower().str.contains(t).astype(int)
    return output_df

# %%
create_boolean_feature(train_df).sum()
# Out:
# Platform_has_PS    0
# dtype: int64

# %% [markdown]
# 特徴量生成

# %%
class BaseBlock(object):
    def fit(self, input_df, y=None):
        return self.transform(input_df)
        
    def transform(self, input_df):
        raise NotImplementedError()

# %%
# countEncodign
class CountEncodingBlock(BaseBlock):
    def __init__(self, column, whole_df: pd.DataFrame):
        self.column = column
        self.whole_df = whole_df

    def transform(self, input_df):
        output_df = pd.DataFrame()
        c = self.column
        
        vc = self.whole_df[c].value_counts()
        output_df[c] = input_df[c].map(vc)
        return output_df.add_prefix('CE_')

# %%
class OneHotBlock(BaseBlock):
    def __init__(self, column: str):
        self.column = column
        self.cats_ = None
        
    def fit(self, input_df, y=None):
        vc = input_df[self.column].dropna().value_counts()
        cats = vc[vc > 40].index
        self.cats_ = cats
        return self.transform(input_df)
    
    def transform(self, input_df):
        x = pd.Categorical(input_df[self.column], categories=self.cats_)
        out_df = pd.get_dummies(x, dummy_na=False)
        out_df.columns = out_df.columns.tolist()
        return out_df.add_prefix(f'OH_{self.column}=')

# %%
custom_pipeline = [preprocessing.fillna
                   , preprocessing.lowercase
                   , preprocessing.remove_digits
                   , preprocessing.remove_punctuation
                   , preprocessing.remove_diacritics
                   , preprocessing.remove_whitespace
                   , preprocessing.remove_stopwords
                  ]

# %%
from nltk.util import ngrams

def line_ngram(line, n=2):
    words = [w for w in line.split(' ') if len(w) != 0] # 空文字は取り除く
    return list(ngrams(words, n))

# %%
def clearn_by_hero(x):
    custom_pipeline = [preprocessing.fillna
                   , preprocessing.lowercase
                   , preprocessing.remove_digits
                   , preprocessing.remove_punctuation
                   , preprocessing.remove_diacritics
                   , preprocessing.remove_whitespace
                   , preprocessing.remove_stopwords
                  ]
    return hero.clean(x, custom_pipeline)

def create_n_gram(x, n=3):
    x = clearn_by_hero(x)
    x = pd.Series(x).map(lambda r: line_ngram(r, n=n))
    return x

class NameNGramBlock(BaseBlock):
    def __init__(self, whole_df, n=3):
        self.whole_df = whole_df
        self.n = n
    
    def fit(self, input_df, y=None):
        name_grams = create_n_gram(self.whole_df['Name'], n=self.n)
        grams = [x for row in name_grams for x in row if len(x) > 0]
        top_grams = pd.Series(grams).value_counts().head(20).index
        
        self.top_grams_ = top_grams
        return self.transform(input_df)
    
    def transform(self, input_df):
        name_grams = create_n_gram(input_df['Name'], n=self.n)
        output_df = pd.DataFrame()
        
        for top in self.top_grams_:
            s_top = '-'.join(top)
            output_df[f'{s_top}'] = name_grams.map(lambda x: top in x).map(int)

        return output_df.add_prefix('Name_has_').add_suffix(f'_n={self.n}')

# %%
sales_columns = train_df.columns[train_df.columns.str.contains('Sales')].tolist()
sales_columns = sorted(sales_columns)

class SalesPortfolioBlock(BaseBlock):
    """売上ポートフォリオ"""
    
    def __init__(self, key: str):
        self.key = key    
        self.meta_df = None
    
    def fit(self, input_df):
        _df = input_df[sales_columns].groupby(input_df[self.key]).sum()
        _df = (_df.T / _df.sum(axis=1)).T
        self.meta_df = _df
        return self.transform(input_df)
    
    def transform(self, input_df):
        out_df = pd.merge(input_df[self.key], self.meta_df, on=self.key, how='left').drop(columns=[self.key])
        out_df = out_df.add_prefix(f'SP@{self.key}_')
        return out_df

# %%
class WrapperBlock(BaseBlock):
    def __init__(self, function):
        self.function = function
        
    def transform(self, input_df):
        return self.function(input_df)

# %%
# https://github.com/nyk510/vivid/blob/master/vivid/utils.py
from contextlib import contextmanager
from time import time

@contextmanager
def timer(logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None):
    if prefix: format_str = str(prefix) + format_str
    if suffix: format_str = format_str + str(suffix)
    start = time()
    yield
    d = time() - start
    out_str = format_str.format(d)
    if logger:
        logger.info(out_str)
    else:
        print(out_str)

# %%
whole_df = pd.concat([train_df, test_df], ignore_index=True)

# %%
ohb_list = ['Platform', 'Genre', 'Rating', 'Publisher', 'Kmeans']

ceb_list = ['Name', 'Platform', 'Genre', 'Year_of_Release', 'Year_category', 'Platform_and_Genre', 'Violence']

srpb_list = ['Genre', 'Platform', 'Violence']

process_blocks = [
    WrapperBlock(create_continuous_features),
    # WrapperBlock(_categolize_year),
    # WrapperBlock(create_boolean_feature),
    NameNGramBlock(whole_df, n=3),
    *[OneHotBlock(c) for c in ohb_list],
    *[CountEncodingBlock(c, whole_df=whole_df) for c in ceb_list],
    *[SalesPortfolioBlock(c) for c in srpb_list]
]

# %%
process_blocks
# Out:
# [<__main__.WrapperBlock at 0x12e148940>,
#  <__main__.NameNGramBlock at 0x12e148f40>,
#  <__main__.OneHotBlock at 0x12c56e670>,
#  <__main__.OneHotBlock at 0x12c56e820>,
#  <__main__.OneHotBlock at 0x12b5f96d0>,
#  <__main__.OneHotBlock at 0x12e0ee9a0>,
#  <__main__.OneHotBlock at 0x12e0eeca0>,
#  <__main__.CountEncodingBlock at 0x12e0eef40>,
#  <__main__.CountEncodingBlock at 0x12e0ee190>,
#  <__main__.CountEncodingBlock at 0x12e0eedc0>,
#  <__main__.CountEncodingBlock at 0x12d0baa00>,
#  <__main__.CountEncodingBlock at 0x12d0ba670>,
#  <__main__.CountEncodingBlock at 0x12d0ba190>,
#  <__main__.CountEncodingBlock at 0x12d0ba3a0>,
#  <__main__.SalesPortfolioBlock at 0x12aaf07f0>,
#  <__main__.SalesPortfolioBlock at 0x12aaf0a00>,
#  <__main__.SalesPortfolioBlock at 0x12aaf0910>]

# %%
from tqdm import tqdm


def get_function(block, is_train):
    s = mapping = {
        True: 'fit',
        False: 'transform'
    }.get(is_train)
    return getattr(block, s)
    

def to_feature(input_df, 
               blocks,
               is_train=False):
    out_df = pd.DataFrame()
    
    for block in tqdm(blocks, total=len(blocks)):
        func = get_function(block, is_train)
        
        with timer(prefix='create ' + str(block) + ' '):
            _df = func(input_df)
        
        assert len(_df) == len(input_df), func.__name__
        out_df = pd.concat([out_df, _df], axis=1)
        
    return out_df

# %%
train_feat_df = to_feature(train_df, process_blocks, is_train=True)
test_feat_df = to_feature(test_df, process_blocks)
# Out:
#   0%|          | 0/17 [00:00<?, ?it/s]create <__main__.WrapperBlock object at 0x12e148940> 0.009[s]
# 100%|██████████| 17/17 [00:00<00:00, 18.15it/s]
#   0%|          | 0/17 [00:00<?, ?it/s]create <__main__.NameNGramBlock object at 0x12e148f40> 0.769[s]
# create <__main__.OneHotBlock object at 0x12c56e670> 0.005[s]
# create <__main__.OneHotBlock object at 0x12c56e820> 0.004[s]
# create <__main__.OneHotBlock object at 0x12b5f96d0> 0.004[s]
# create <__main__.OneHotBlock object at 0x12e0ee9a0> 0.004[s]
# create <__main__.OneHotBlock object at 0x12e0eeca0> 0.002[s]
# create <__main__.CountEncodingBlock object at 0x12e0eef40> 0.010[s]
# create <__main__.CountEncodingBlock object at 0x12e0ee190> 0.005[s]
# create <__main__.CountEncodingBlock object at 0x12e0eedc0> 0.005[s]
# create <__main__.CountEncodingBlock object at 0x12d0baa00> 0.003[s]
# create <__main__.CountEncodingBlock object at 0x12d0ba670> 0.004[s]
# create <__main__.CountEncodingBlock object at 0x12d0ba190> 0.006[s]
# create <__main__.CountEncodingBlock object at 0x12d0ba3a0> 0.004[s]
# create <__main__.SalesPortfolioBlock object at 0x12aaf07f0> 0.009[s]
# create <__main__.SalesPortfolioBlock object at 0x12aaf0a00> 0.008[s]
# create <__main__.SalesPortfolioBlock object at 0x12aaf0910> 0.008[s]
# create <__main__.WrapperBlock object at 0x12e148940> 0.008[s]
# 100%|██████████| 17/17 [00:00<00:00, 40.83it/s]create <__main__.NameNGramBlock object at 0x12e148f40> 0.273[s]
# create <__main__.OneHotBlock object at 0x12c56e670> 0.002[s]
# create <__main__.OneHotBlock object at 0x12c56e820> 0.002[s]
# create <__main__.OneHotBlock object at 0x12b5f96d0> 0.002[s]
# create <__main__.OneHotBlock object at 0x12e0ee9a0> 0.002[s]
# create <__main__.OneHotBlock object at 0x12e0eeca0> 0.001[s]
# create <__main__.CountEncodingBlock object at 0x12e0eef40> 0.011[s]
# create <__main__.CountEncodingBlock object at 0x12e0ee190> 0.006[s]
# create <__main__.CountEncodingBlock object at 0x12e0eedc0> 0.005[s]
# create <__main__.CountEncodingBlock object at 0x12d0baa00> 0.004[s]
# create <__main__.CountEncodingBlock object at 0x12d0ba670> 0.005[s]
# create <__main__.CountEncodingBlock object at 0x12d0ba190> 0.006[s]
# create <__main__.CountEncodingBlock object at 0x12d0ba3a0> 0.004[s]
# create <__main__.SalesPortfolioBlock object at 0x12aaf07f0> 0.004[s]
# create <__main__.SalesPortfolioBlock object at 0x12aaf0a00> 0.005[s]
# create <__main__.SalesPortfolioBlock object at 0x12aaf0910> 0.004[s]

# %%
train_feat_df.head()
# Out:
#    Critic_Score  Critic_Count  User_Score  User_Count  Year_of_Release  \
# 0          74.0          17.0         7.9        22.0              NaN
# 1          78.0          22.0         6.6        28.0              NaN
# 2          73.0           5.0         7.4        10.0              NaN
# 3           NaN           NaN         NaN         NaN              NaN
# 4          76.0           8.0         7.8        13.0              NaN
#
#    User_Score_is_tbd  User_Count_times_Score  Critic_Count_times_Score  \
# 0                  0                   173.8                    1258.0
# 1                  0                   184.8                    1716.0
# 2                  0                    74.0                     365.0
# 3                  0                     NaN                       NaN
# 4                  0                   101.4                     608.0
#
#    Mean_Critic_Score  Mean_User_Score  ...  SP@Platform_EU_Sales  \
# 0           4.352941         0.359091  ...              0.146605
# 1           3.545455         0.235714  ...              0.146605
# 2          14.600000         0.740000  ...              0.116650
# 3                NaN              NaN  ...              0.028295
# 4           9.500000         0.600000  ...              0.146605
#
#    SP@Platform_Global_Sales  SP@Platform_JP_Sales  SP@Platform_NA_Sales  \
# 0                  0.500048              0.047349              0.262328
# 1                  0.500048              0.047349              0.262328
# 2                  0.500295              0.122345              0.186758
# 3                  0.500282              0.000000              0.466765
# 4                  0.500048              0.047349              0.262328
#
#    SP@Platform_Other_Sales  SP@Violence_EU_Sales  SP@Violence_Global_Sales  \
# 0                 0.043671              0.136268                  0.500145
# 1                 0.043671              0.136268                  0.500145
# 2                 0.073951              0.136268                  0.500145
# 3                 0.004657                   NaN                       NaN
# 4                 0.043671              0.136268                  0.500145
#
#    SP@Violence_JP_Sales  SP@Violence_NA_Sales  SP@Violence_Other_Sales
# 0              0.062626              0.253578                 0.047384
# 1              0.062626              0.253578                 0.047384
# 2              0.062626              0.253578                 0.047384
# 3                   NaN                   NaN                      NaN
# 4              0.062626              0.253578                 0.047384
#
# [5 rows x 128 columns]

# %% [markdown]
# # LightGBMによる学習

# %%
import lightgbm as lgbm
import xgboost as xgb

from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import mean_squared_error

def fit_lgbm(X, 
             y, 
             cv, 
             params: dict=None, 
             verbose: int=50):
    """lightGBM を CrossValidation の枠組みで学習を行なう function"""
    metric_func = mean_squared_error
    
    # パラメータがないときは、空の dict で置き換える
    if params is None:
        params = {}

    models = []
    # training data の target と同じだけのゼロ配列を用意
    # float にしないと悲しい事件が起こるのでそこだけ注意
    oof_pred = np.zeros_like(y, dtype=np.float)

    for i, (idx_train, idx_valid) in enumerate(cv): 
        # この部分が交差検証のところです。データセットを cv instance によって分割します
        # training data を trian/valid に分割
        x_train, y_train = X[idx_train], y[idx_train]
        x_valid, y_valid = X[idx_valid], y[idx_valid]

        clf = lgbm.LGBMRegressor(**params)
        
        with timer(prefix='fit fold={} '.format(i + 1)):
            clf.fit(x_train, y_train, 
                    eval_set=[(x_valid, y_valid)],  
                    early_stopping_rounds=verbose,
                    verbose=verbose)

        pred_i = clf.predict(x_valid)
        
        oof_pred[idx_valid] = pred_i
        models.append(clf)

        print(f'Fold {i} RMSLE: {metric_func(y_valid, pred_i) ** .5:.4f}')

    score = metric_func(y, oof_pred) ** .5
    print('FINISHED | Whole RMSLE: {:.4f}'.format(score))
    return oof_pred, models

# %%
params = {
    'objective': 'rmse', # 目的関数. これの意味で最小となるようなパラメータを探します. 
    'learning_rate': .1, # 学習率. 小さいほどなめらかな決定境界が作られて性能向上に繋がる場合が多いです、がそれだけ木を作るため学習に時間がかかります
    'max_depth': 6, # 木の深さ. 深い木を許容するほどより複雑な交互作用を考慮するようになります
    'n_estimators': 10000, # 木の最大数. early_stopping という枠組みで木の数は制御されるようにしていますのでとても大きい値を指定しておきます.
    'colsample_bytree': .5, # 木を作る際に考慮する特徴量の割合. 1以下を指定すると特徴をランダムに欠落させます。小さくすることで, まんべんなく特徴を使うという効果があります.
    'importance_type': 'gain' # 特徴重要度計算のロジック(後述)
}

y = train_df['Global_Sales'].values
y = np.log1p(y) # log + plus1 変換する RMSLEと同じ指標にする小技

# %%
from sklearn.model_selection import KFold, GroupKFold

fold = KFold(n_splits=5, shuffle=True, random_state=71)
cv = list(fold.split(train_feat_df, y)) # もともとが generator なため明示的に list に変換する

# %%
oof, models = fit_lgbm(train_feat_df.values, y, cv, params=params)
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 0.925424
# [100]	valid_0's rmse: 0.899248
# [150]	valid_0's rmse: 0.89411
# [200]	valid_0's rmse: 0.893743
# [250]	valid_0's rmse: 0.893319
# Early stopping, best iteration is:
# [220]	valid_0's rmse: 0.892412
# fit fold=1 0.512[s]
# Fold 0 RMSLE: 0.8924
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 0.939162
# [100]	valid_0's rmse: 0.913267
# [150]	valid_0's rmse: 0.900822
# [200]	valid_0's rmse: 0.896948
# [250]	valid_0's rmse: 0.893579
# [300]	valid_0's rmse: 0.891583
# [350]	valid_0's rmse: 0.89211
# Early stopping, best iteration is:
# [310]	valid_0's rmse: 0.890903
# fit fold=2 0.475[s]
# Fold 1 RMSLE: 0.8909
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 0.887437
# [100]	valid_0's rmse: 0.865118
# [150]	valid_0's rmse: 0.857872
# [200]	valid_0's rmse: 0.856537
# [250]	valid_0's rmse: 0.85568
# [300]	valid_0's rmse: 0.854288
# Early stopping, best iteration is:
# [292]	valid_0's rmse: 0.853632
# fit fold=3 0.464[s]
# Fold 2 RMSLE: 0.8536
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 0.933627
# [100]	valid_0's rmse: 0.90612
# [150]	valid_0's rmse: 0.896166
# [200]	valid_0's rmse: 0.893254
# [250]	valid_0's rmse: 0.889867
# [300]	valid_0's rmse: 0.88697
# [350]	valid_0's rmse: 0.886084
# [400]	valid_0's rmse: 0.885831
# [450]	valid_0's rmse: 0.885642
# [500]	valid_0's rmse: 0.885464
# [550]	valid_0's rmse: 0.88586
# Early stopping, best iteration is:
# [510]	valid_0's rmse: 0.88467
# fit fold=4 0.897[s]
# Fold 3 RMSLE: 0.8847
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 0.913198
# [100]	valid_0's rmse: 0.890841
# [150]	valid_0's rmse: 0.880799
# [200]	valid_0's rmse: 0.877568
# [250]	valid_0's rmse: 0.876801
# [300]	valid_0's rmse: 0.8771
# Early stopping, best iteration is:
# [261]	valid_0's rmse: 0.876278
# fit fold=5 0.409[s]
# Fold 4 RMSLE: 0.8763
# FINISHED | Whole RMSLE: 0.8797

# %%
# Group KFold
def split_by_groups(groups):
    kfold = KFold(n_splits=10, random_state=71, shuffle=True)
    groups = pd.Series(groups)
    
    unique_groups = groups.unique()
    splits = []
    
    def _filter_ids(idx):
        values = unique_groups[idx]
        idx = groups.isin(values)
        return groups[idx].index.values
    
    for idx_tr, idx_val in kfold.split(unique_groups):
        splits.append([
            _filter_ids(idx_tr), _filter_ids(idx_val)
        ])
        
    return splits

# %%
cv = split_by_groups(train_df['Genre'])
g_oof, g_models = fit_lgbm(train_feat_df.values, y, cv, params=params)
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 1.03081
# [100]	valid_0's rmse: 1.014
# [150]	valid_0's rmse: 1.01115
# [200]	valid_0's rmse: 1.01167
# Early stopping, best iteration is:
# [152]	valid_0's rmse: 1.01013
# fit fold=1 0.370[s]
# Fold 0 RMSLE: 1.0101
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 1.04585
# [100]	valid_0's rmse: 1.02517
# [150]	valid_0's rmse: 1.0213
# [200]	valid_0's rmse: 1.02
# Early stopping, best iteration is:
# [178]	valid_0's rmse: 1.01927
# fit fold=2 0.306[s]
# Fold 1 RMSLE: 1.0193
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 0.968866
# [100]	valid_0's rmse: 0.95345
# [150]	valid_0's rmse: 0.953946
# Early stopping, best iteration is:
# [118]	valid_0's rmse: 0.951317
# fit fold=3 0.230[s]
# Fold 2 RMSLE: 0.9513
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 0.948414
# [100]	valid_0's rmse: 0.931851
# [150]	valid_0's rmse: 0.927765
# Early stopping, best iteration is:
# [138]	valid_0's rmse: 0.927139
# fit fold=4 0.301[s]
# Fold 3 RMSLE: 0.9271
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 0.903154
# [100]	valid_0's rmse: 0.881752
# [150]	valid_0's rmse: 0.87334
# [200]	valid_0's rmse: 0.872208
# [250]	valid_0's rmse: 0.868043
# [300]	valid_0's rmse: 0.868449
# Early stopping, best iteration is:
# [258]	valid_0's rmse: 0.866558
# fit fold=5 0.786[s]
# Fold 4 RMSLE: 0.8666
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 0.973149
# [100]	valid_0's rmse: 0.955097
# [150]	valid_0's rmse: 0.947377
# [200]	valid_0's rmse: 0.944349
# [250]	valid_0's rmse: 0.943219
# Early stopping, best iteration is:
# [208]	valid_0's rmse: 0.942059
# fit fold=6 0.595[s]
# Fold 5 RMSLE: 0.9421
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 1.03037
# [100]	valid_0's rmse: 1.03572
# Early stopping, best iteration is:
# [54]	valid_0's rmse: 1.02966
# fit fold=7 0.364[s]
# Fold 6 RMSLE: 1.0297
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 0.84756
# [100]	valid_0's rmse: 0.815301
# [150]	valid_0's rmse: 0.807546
# [200]	valid_0's rmse: 0.804258
# [250]	valid_0's rmse: 0.80396
# [300]	valid_0's rmse: 0.807468
# Early stopping, best iteration is:
# [254]	valid_0's rmse: 0.802812
# fit fold=8 0.467[s]
# Fold 7 RMSLE: 0.8028
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 1.1024
# [100]	valid_0's rmse: 1.08795
# [150]	valid_0's rmse: 1.07873
# [200]	valid_0's rmse: 1.0786
# [250]	valid_0's rmse: 1.07573
# [300]	valid_0's rmse: 1.07595
# Early stopping, best iteration is:
# [255]	valid_0's rmse: 1.07459
# fit fold=9 0.660[s]
# Fold 8 RMSLE: 1.0746
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 50 rounds
# [50]	valid_0's rmse: 0.820949
# [100]	valid_0's rmse: 0.826593
# Early stopping, best iteration is:
# [62]	valid_0's rmse: 0.81678
# fit fold=10 0.304[s]
# Fold 9 RMSLE: 0.8168
# FINISHED | Whole RMSLE: 0.9591

# %%
def visualize_importance(models, feat_train_df):
    """lightGBM の model 配列の feature importance を plot する
    CVごとのブレを boxen plot として表現します.
    
    args:
        models:
            List of lightGBM models
        feat_train_df:
            学習時に使った DataFrame
    """
    feature_importance_df = pd.DataFrame()
    for i, model in enumerate(models):
        _df = pd.DataFrame()
        _df['feature_importance'] = model.feature_importances_
        _df['column'] = feat_train_df.columns
        _df['fold'] = i + 1
        feature_importance_df = pd.concat([feature_importance_df, _df], axis=0, ignore_index=True)

    order = feature_importance_df.groupby('column')\
        .sum()[['feature_importance']]\
        .sort_values('feature_importance', ascending=False).index[:50]

    fig, ax = plt.subplots(figsize=(max(6, len(order) * .4), 7))
    sns.boxenplot(data=feature_importance_df, x='column', y='feature_importance', order=order, ax=ax, palette='viridis')
    ax.tick_params(axis='x', rotation=90)
    ax.grid()
    fig.tight_layout()
    return fig, ax

# %%
fig, ax = visualize_importance(models, train_feat_df)

# %%
fig, ax = visualize_importance(g_models, train_feat_df)

# %%
from datetime import datetime

# subNum = 3
now = datetime.now().strftime('%Y%m%d%H%M%S')
sub_file = 'submission_{}.csv'.format(now)
g_sub_file = 'submission_g_{}.csv'.format(now)

#KFold
pred = np.array([model.predict(test_feat_df.values) for model in models])
pred = np.mean(pred, axis=0)
pred = np.expm1(pred)
pred = np.where(pred < 0, 0, pred)
sub_df = pd.DataFrame({ 'Global_Sales': pred })
sub_df.to_csv(os.path.join(OUTPUT_DIR, sub_file), index=False)

#GroupKFold
g_pred = np.array([model.predict(test_feat_df.values) for model in g_models])
g_pred = np.mean(g_pred, axis=0)
g_pred = np.expm1(g_pred)
g_pred = np.where(g_pred < 0, 0, g_pred)
g_sub_df = pd.DataFrame({ 'Global_Sales': g_pred })
g_sub_df.to_csv(os.path.join(OUTPUT_DIR, g_sub_file), index=False)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
sns.distplot(np.log1p(pred), label='Test Predict')
sns.distplot(oof, label='Out Of Fold')
ax.legend()
ax.grid()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
sns.distplot(np.log1p(pred), label='Test Predict')
sns.distplot(g_oof, label='Out Of Fold')
ax.legend()
ax.grid()
